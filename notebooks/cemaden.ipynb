# %%
import requests
from io import StringIO
import pandas as pd
import pandasql as psql
import codecs
import folium
# import bearcart
import bokeh
import matplotlib.pyplot as plt
import mpld3
from IPython.display import HTML

# %%
mpld3.enable_notebook()
folium.initialize_notebook()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: FutureWarning: initialize_notebook is deprecated and no longer required.
#   from ipykernel import kernelapp as app

# %%
base_url="http://150.163.255.246:18383/dados_rede"
url_pcd = "http://150.163.255.246:18383/dados_pcd"

# %%
chave = "bc10602ea62759fab1578f8eb1ff6f7abbf8678d"

# %% [markdown]
# # Testando a captura

# %%
results = requests.get(base_url,params={'chave': chave,
                                        'inicio': 201412010000,
                                        'fim': 201412010300,
                                        'uf': "RJ"})
dfrj = pd.read_csv(StringIO(results.text), sep=';', encoding='win-1232',skiprows=1)
dfrj[dfrj['cod.estacao']=='330575202A'].head()
# with codecs.open('clima.csv', 'w', encoding='utf-8') as fd:
#     fd.write(results.text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-54-95fb8597fe6e> in <module>()
#       3                                         'fim': 201412010300,
#       4                                         'uf': "RJ"})
# ----> 5 dfrj = pd.read_csv(StringIO(results.text), sep=';', encoding='win-1232',skiprows=1)
#       6 dfrj[dfrj['cod.estacao']=='330575202A'].head()
#       7 # with codecs.open('clima.csv', 'w', encoding='utf-8') as fd:
#
# ...

# %% [markdown]
# Vamos agora puxar dados de uma estação específica:

# %%
estacao = "120040101A"
results = requests.get(url_pcd,params={'chave': chave,
                                        'inicio': 201412010000,
                                        'fim': 201412012359,
                                        'codigo':"120040101A"})

dfest = pd.read_csv(StringIO(results.text), sep=';', encoding='latin-1',skiprows=1)
dfest.head()
# Out:
#   cod.estacao    nome   municipio  uf  latitude  longitude  \
# 0  120040101A  AC Oca  RIO BRANCO  AC -9.972969 -67.806662
# 1  120040101A  AC Oca  RIO BRANCO  AC -9.972969 -67.806662
# 2  120040101A  AC Oca  RIO BRANCO  AC -9.972969 -67.806662
# 3  120040101A  AC Oca  RIO BRANCO  AC -9.972969 -67.806662
# 4  120040101A  AC Oca  RIO BRANCO  AC -9.972969 -67.806662
#
#               datahora sensor  valor  offset
# 0  2014-12-01 00:00:00  chuva    0.0     NaN
# 1  2014-12-01 01:00:00  chuva    0.0     NaN
# 2  2014-12-01 02:00:00  chuva    0.0     NaN
# 3  2014-12-01 03:00:00  chuva    0.0     NaN
# 4  2014-12-01 04:00:00  chuva    0.0     NaN

# %%
print(results.encoding)
results.status_code
# Out:
# None
# 200

# %%
dfrj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2307 entries, 0 to 2306
# Data columns (total 10 columns):
# cod.estacao    2307 non-null object
# nome           2307 non-null object
# municipio      2307 non-null object
# uf             2307 non-null object
# latitude       2307 non-null float64
# longitude      2307 non-null float64
# datahora       2307 non-null object
# sensor         2307 non-null object
# valor          2307 non-null float64
# offset         65 non-null float64
# dtypes: float64(4), object(6)
# memory usage: 180.3+ KB

# %% [markdown]
# Agora vamos ver quantas estações existem no estado do Rio de Janeiro.

# %%
est_rj = set(dfrj['cod.estacao'])
len(est_rj)
# Out:
# 235

# %% [markdown]
# Se agruparmos por município, timestamp, sensor e latitude, dá para ter uma ideia de quantas estações por município temos:

# %%
grouped=dfrj.groupby(['municipio','cod.estacao'])
grouped.all()
# Out:
#                               datahora latitude longitude  nome offset sensor  \
# municipio         cod.estacao
# ANGRA DOS REIS    330010001A      True     True      True  True   True   True
#                   330010002A      True     True      True  True   True   True
#                   330010003A      True     True      True  True   True   True
#                   330010006A      True     True      True  True   True   True
#                   330010007A      True     True      True  True   True   True
#                   330010008A      True     True      True  True   True   True
#                   330010009A      True     True      True  True   True   True
#                   330010010A      True     True      True  True   True   True
#                   330010011A      True     True      True  True   True   True
#                   330010012A      True     True      True  True   True   True
#                   330010013A      True     True      True  True   True   True
# ...

# %% [markdown]
# ## Visualizando as estações no mapa

# %%
def inline_map(m, width=650, height=500):
    """Takes a folium instance and embed HTML."""
    #m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{}" '
                 'style="width: {}px; height: {}px; '
                 'border: none"></iframe>'.format(srcdoc, width, height))
    return embed
    

width, height = 650, 480
mapa_rj = folium.Map(location=[-22.9068, -43.1729], zoom_start=8, tiles='OpenStreetMap', width=width, height=height)
mapa_rj.lat_lng_popover()

ploted_stations = set([])
for row in dfrj.iterrows():
    lat = row[1]['latitude']
    lon = row[1]['longitude']
    if (lat,lon) in ploted_stations:
        continue
    nome = row[1]['nome']
    cod = row[1]['cod.estacao']
    marker = mapa_rj.circle_marker(location=[lat, lon], 
                                    fill_color='#f4bf75', 
                                    radius=22,
                                   popup='Nome: {}\nCodigo: {}'.format(nome, cod)
                                   )
    ploted_stations.add((lat,lon))
print (len(ploted_stations))

inline_map(mapa_rj, width,height)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:13: FutureWarning: lat_lng_popover is deprecated. Use add_children(LatLngPopup) instead
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:26: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
# 235
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-bae76e2f84ba> in <module>()
#      29 print (len(ploted_stations))
#      30
# ---> 31 inline_map(mapa_rj, width,height)
#
# <ipython-input-39-bae76e2f84ba> in inline_map(m, width, height)
#       2     """Takes a folium instance and embed HTML."""
#       3     #m._build_map()
# ----> 4     srcdoc = m.HTML.replace('"', '&quot;')
#       5     embed = HTML('<iframe srcdoc="{}" '
#       6                  'style="width: {}px; height: {}px; '
#
# AttributeError: 'Map' object has no attribute 'HTML'

# %%
mapa_rj.create_map?

# %%
df = pd.read_csv('clima_{}.csv'.format(estacao), sep=";",skiprows=1)
df

# %%
results.headers.items()
